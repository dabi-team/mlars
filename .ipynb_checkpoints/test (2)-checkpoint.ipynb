# %%
import pandas as pd
import numpy as np
from mlars import main

df = pd.read_csv("datasets/heart.csv", encoding= 'unicode_escape')
resultdf = main(df, "HeartDisease") 

import matplotlib.pyplot as plt
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]
# (918, 21)
# with dataframe of shape: 918 21
# SVMmodel fit done with params 0.1 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.2 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.3 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.4 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.5 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.6 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.7 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.8 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 0.9 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# SVMmodel fit done with params 1 0.5706521739130435
# 0.28532608695652173
# 0.4298250150443809
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic Regressionmodel fit done with params l2 0.8315217391304348
# 0.8303439803439803
# 0.8281591735346111
# logistic Regressionmodel fit done with params none 0.842391304347826
# 0.8416461916461917
# 0.8392716499617796
# Random Forestmodel fit done with params 80 0.8478260869565217
# 0.8480809576699988
# 0.8447527693909995
# Random Forestmodel fit done with params 90 0.8695652173913043
# 0.8753623188405797
# 0.8670931826407886
# Random Forestmodel fit done with params 100 0.8532608695652174
# 0.8567669172932331
# 0.8502496827265801
# Gaussian Naive Bayesmodel fit done with params 1e-09 0.8478260869565217
# 0.8466055045871559
# 0.8449233149898139
# Gaussian Naive Bayesmodel fit done with params 1e-08 0.8478260869565217
# 0.8466055045871559
# 0.8449233149898139
# Gaussian Naive Bayesmodel fit done with params 1e-07 0.8478260869565217
# 0.8466055045871559
# 0.8449233149898139
# Gaussian Naive Bayesmodel fit done with params 1e-06 0.8532608695652174
# 0.8529484029484029
# 0.8503841263889481
# Gaussian Naive Bayesmodel fit done with params 1e-05 0.8206521739130435
# 0.8179824561403509
# 0.8173414015890729
# Gaussian Naive Bayesmodel fit done with params 0.0001 0.8043478260869565
# 0.8001917775380558
# 0.8018575037253749
# Gaussian Naive Bayesmodel fit done with params 0.001 0.7228260869565217
# 0.7228260869565217
# 0.7236134063980257
# Gaussian Naive Bayesmodel fit done with params 0.01 0.6793478260869565
# 0.6847413383958234
# 0.6826689179601776
# Gaussian Naive Bayesmodel fit done with params 0.1 0.6358695652173914
# 0.6825268817204301
# 0.6535136483836057
# Gaussian Naive Bayesmodel fit done with params 1.0 0.5434782608695652
# 0.5822627434728553
# 0.5585971212547262
# KNNmodel fit done with params 1 0.6847826086956522
# 0.6826729745712596
# 0.6840082598914716
# KNNmodel fit done with params 2 0.6141304347826086
# 0.6422413793103448
# 0.6260951065128063
# KNNmodel fit done with params 3 0.6793478260869565
# 0.6730769230769231
# 0.6748350964888621
# KNNmodel fit done with params 4 0.6793478260869565
# 0.6918269230769231
# 0.6857295418008024
# KNNmodel fit done with params 5 0.6902173913043478
# 0.6847202295552368
# 0.6866236522731031
# KNNmodel fit done with params 6 0.6630434782608695
# 0.6739781853050462
# 0.6687525643126779
# KNNmodel fit done with params 7 0.7065217391304348
# 0.7032823794288423
# 0.7050753704851982
# KNNmodel fit done with params 8 0.6902173913043478
# 0.7002630320420851
# 0.6956360788782927
# KNNmodel fit done with params 9 0.7282608695652174
# 0.7261975162625665
# 0.7278023601700261
# KNNmodel fit done with params 10 0.7119565217391305
# 0.7174893213099194
# 0.7154903413224855
# Decision Treemodel fit done with params gini 0.782608695652174
# 0.7783609686269832
# 0.7804348850300268
# Decision Treemodel fit done with params entropy 0.7608695652173914
# 0.7564117857568889
# 0.7584536931417241
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# This Algorithm is not supported
# Bernoulli Naive Bayesmodel fit done with params 0.0 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.1 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.2 0.8315217391304348
# 0.8337092731829574
# C:\Users\haide\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\naive_bayes.py:555: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn(
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.3 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.4 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.5 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.6 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.7 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.8 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 0.9 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# Bernoulli Naive Bayesmodel fit done with params 1 0.8315217391304348
# 0.8337092731829574
# 0.8278661700265202
# AdaBoostmodel fit done with params None 0.8532608695652174
# 0.8516081871345029
# 0.8505781087031037
# AdaBoostmodel fit done with params DecisionTreeClassifier() 0.7880434782608695
# 0.7840476190476191
# 0.78624510069443
# AdaBoostmodel fit done with params GaussianNB() 0.6684782608695652
# 0.672089552238806
# 0.6538795097617446
# AdaBoostmodel fit done with params BernoulliNB() 0.8369565217391305
# 0.8343245539507222
# 0.8341100057758495
# Gradient Boostingmodel fit done with params 0.1 0.8695652173913043
# 0.8753623188405797
# 0.8670931826407886
# Gradient Boostingmodel fit done with params 0.2 0.8641304347826086
# 0.8740369799691834
# 0.8617705283531212
# Gradient Boostingmodel fit done with params 0.3 0.8260869565217391
# 0.8341305753070459
# 0.8223127715446987
# Gradient Boostingmodel fit done with params 0.4 0.8315217391304348
# 0.8416666666666667
# 0.8280607625420504
# Gradient Boostingmodel fit done with params 0.5 0.8260869565217391
# 0.8289855072463768
# 0.8222361845366799
# Gradient Boostingmodel fit done with params 0.6 0.842391304347826
# 0.8476166328600405
# 0.8390795500897228
# Gradient Boostingmodel fit done with params 0.7 0.8315217391304348
# 0.8416666666666667
# 0.8280607625420504
# Gradient Boostingmodel fit done with params 0.8 0.8206521739130435
# 0.8190417690417691
# 0.8170466971074426
# Gradient Boostingmodel fit done with params 0.9 0.8206521739130435
# 0.824290060851927
# 0.8166038111528894
# Gradient Boostingmodel fit done with params 1 0.8043478260869565
# 0.8078836586299273
# 0.7997052852707135
# Extra Treesmodel fit done with params 1 0.8315217391304348
# 0.8303439803439803
# 0.8281591735346111
# Extra Treesmodel fit done with params 2 0.717391304347826
# 0.7218864794406921
# 0.7204680602547628
# Extra Treesmodel fit done with params 3 0.8478260869565217
# 0.8480809576699988
# 0.8447527693909995
# Extra Treesmodel fit done with params 4 0.8478260869565217
# 0.8447257383966245
# 0.8455008255365988
# Extra Treesmodel fit done with params 5 0.8260869565217391
# 0.8240978593272171
# 0.8227329098782719
# Extra Treesmodel fit done with params 6 0.8043478260869565
# 0.8008253428814176
# 0.8009193369242643
# Extra Treesmodel fit done with params 7 0.8260869565217391
# 0.823158150260954
# 0.8230464494919877
# Extra Treesmodel fit done with params 8 0.8206521739130435
# 0.8169047619047619
# 0.8191895879154566
# Extra Treesmodel fit done with params 9 0.8260869565217391
# 0.8222461944144792
# 0.8238802460500001
# Extra Treesmodel fit done with params 10 0.8206521739130435
# 0.8172472181906144
# 0.8177048464175863
# done
# best model is : Random Forest ,with accuracy  0.8670931826407886
#            Name Params  Accuracy  Precision    Recall        F1   Average
# 0   Extra Trees     10  0.820652   0.817247  0.816215  0.816705  0.817705
# 1   Extra Trees      9  0.826087   0.822246  0.824111  0.823077  0.823880
# 2   Extra Trees      8  0.820652   0.816905  0.820916  0.818285  0.819190
# 3   Extra Trees      7  0.826087   0.823158  0.820976  0.821964  0.823046
# 4   Extra Trees      6  0.804348   0.800825  0.798794  0.799710  0.800919
# ..          ...    ...       ...        ...       ...       ...       ...
# 78          SVM    0.5  0.570652   0.285326  0.500000  0.363322  0.429825
# 79          SVM    0.4  0.570652   0.285326  0.500000  0.363322  0.429825
# 80          SVM    0.3  0.570652   0.285326  0.500000  0.363322  0.429825
# 81          SVM    0.2  0.570652   0.285326  0.500000  0.363322  0.429825
# 82          SVM    0.1  0.570652   0.285326  0.500000  0.363322  0.429825
#
# [83 rows x 7 columns]

# %%
resultdf.insert(0, "model", 0.909354)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 resultdf.insert(0, "model", 0.909354)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert model, already exists

# %%
plt.plot(resultdf["Name"], resultdf["model"],label="Best model (Random Forest)",linestyle='dashed')
plt.plot(resultdf["Name"], resultdf["Average"],label="Average")
plt.plot(resultdf["Name"], resultdf["Accuracy"],label="Accuracy")
plt.plot(resultdf["Name"], resultdf["Recall"],label="Recall")
plt.plot(resultdf["Name"], resultdf["Precision"],label="Precision")
plt.plot(resultdf["Name"], resultdf["F1"],label="F1")
plt.title("Heart Disease")
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
resultdf
# Out:
#        model         Name Params  Accuracy  Precision    Recall        F1  \
# 0   0.909354  Extra Trees     10  0.820652   0.817247  0.816215  0.816705
# 1   0.909354  Extra Trees      9  0.826087   0.822246  0.824111  0.823077
# 2   0.909354  Extra Trees      8  0.820652   0.816905  0.820916  0.818285
# 3   0.909354  Extra Trees      7  0.826087   0.823158  0.820976  0.821964
# 4   0.909354  Extra Trees      6  0.804348   0.800825  0.798794  0.799710
# ..       ...          ...    ...       ...        ...       ...       ...
# 78  0.909354          SVM    0.5  0.570652   0.285326  0.500000  0.363322
# 79  0.909354          SVM    0.4  0.570652   0.285326  0.500000  0.363322
# 80  0.909354          SVM    0.3  0.570652   0.285326  0.500000  0.363322
# 81  0.909354          SVM    0.2  0.570652   0.285326  0.500000  0.363322
# 82  0.909354          SVM    0.1  0.570652   0.285326  0.500000  0.363322
#
#      Average
# 0   0.817705
# 1   0.823880
# 2   0.819190
# 3   0.823046
# 4   0.800919
# ..       ...
# 78  0.429825
# 79  0.429825
# 80  0.429825
# 81  0.429825
# 82  0.429825
#
# [83 rows x 8 columns]
